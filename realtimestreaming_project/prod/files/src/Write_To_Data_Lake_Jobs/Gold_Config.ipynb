# %%
parameters = [
    {"table_name" : "dim_bookings"},
    {"table_name" : "dim_drivers"},
    {"table_name" : "dim_passenger"},
    {"table_name" : "dim_payment_methods"},
    {"table_name" : "dim_ride_status"},
    {"table_name" : "dim_vehicles"},
    {"table_name" : "fact_rides"}
]

# %%
dbutils.jobs.taskValues.set(key="parameters", value=parameters)
