# %%
dbutils.widgets.text("table_name", "")
table_name = dbutils.widgets.get("table_name")

# %%
df = spark.read.table(f"realtime_project.gold.{table_name}")

df.write.format("delta").mode("overwrite").option("mergeSchema", "true").save(f"abfss://gold@realtimejess.dfs.core.windows.net/{table_name}")
